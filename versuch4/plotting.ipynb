# %% [markdown]
# By specifying the path to a cnl_file, you can run the scripts cnl_plot.py and summary.py in this notebook, which also allows the plots to be presented.

# %%
import os

# %% [markdown]
# Aufgabe 1.1 1 TCP Strom CWND

# %%
iperf3 -c 10.11.0.3 -Z -t 60
Connecting to host 10.11.0.3, port 5201
[  5] local 10.11.0.1 port 52822 connected to 10.11.0.3 port 5201
[ ID] Interval           Transfer     Bitrate         Retr  Cwnd
[  5]   0.00-1.00   sec   255 KBytes  2.08 Mbits/sec    0   29.7 KBytes       
[  5]   1.00-2.00   sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]   2.00-3.00   sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]   3.00-4.00   sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]   4.00-5.00   sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]   5.00-6.04   sec   127 KBytes  1.01 Mbits/sec    0   29.7 KBytes       
[  5]   6.04-7.00   sec   127 KBytes  1.08 Mbits/sec    0   29.7 KBytes       
[  5]   7.00-8.00   sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]   8.00-9.00   sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]   9.00-10.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  10.00-11.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  11.00-12.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  12.00-13.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  13.00-14.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  14.00-15.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  15.00-16.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  16.00-17.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  17.00-18.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  18.00-19.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  19.00-20.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  20.00-21.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  21.00-22.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  22.00-23.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  23.00-24.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  24.00-25.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  25.00-26.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  26.00-27.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  27.00-28.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  28.00-29.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  29.00-30.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  30.00-31.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  31.00-32.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  32.00-33.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  33.00-34.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  34.00-35.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  35.00-36.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  36.00-37.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  37.00-38.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  38.00-39.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  39.00-40.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  40.00-41.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  41.00-42.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  42.00-43.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  43.00-44.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  44.00-45.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  45.00-46.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  46.00-47.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  47.00-48.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  48.00-49.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  49.00-50.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  50.00-51.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  51.00-52.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  52.00-53.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  53.00-54.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  54.00-55.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  55.00-56.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  56.00-57.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  57.00-58.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
[  5]  58.00-59.00  sec  63.6 KBytes   521 Kbits/sec    0   29.7 KBytes       
[  5]  59.00-60.00  sec   127 KBytes  1.04 Mbits/sec    0   29.7 KBytes       
- - - - - - - - - - - - - - - - - - - - - - - - -
[ ID] Interval           Transfer     Bitrate         Retr
[  5]   0.00-60.00  sec  6.96 MBytes   973 Kbits/sec    0             sender
[  5]   0.00-60.12  sec  6.85 MBytes   956 Kbits/sec                  receiver

iperf Done.

# %% [markdown]
# Aufgabe 1.2 1 TCP Strom Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011  /tmp/cpunetlog/2024-03-01_11:28:15-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_11:28:15-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_11:28:15",
#         1709288895.7934237
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 1.3 1 TCP Strom Summary

# %%
# %run /CPUnetPLOT/summary.py  /tmp/cpunetlog/2024-03-01_11:28:15-agreeable-agama.cnl
# Out:
# === Summary ===
# Filename:  2024-03-01_11:28:15-agreeable-agama.cnl
# Comment:
# Hostname:  agreeable-agama
# Kernel:    5.15.0-97-generic
#
# Start:     2024-03-01_11:28:19
# End:       2024-03-01_11:29:20
# Duration:  62
#
# CPUs: CPU0, CPU1
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.02 MBits/s
# sv1-eth1.receive:       0.95 MBits/s

# %% [markdown]
# Aufgabe 2.1 2 TCP Ströme Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011  /tmp/cpunetlog/2024-03-01_10:53:55-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_10:53:55-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_10:53:55",
#         1709286835.7220967
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 2.2 2 TCP Ströme summary

# %%
# %run /CPUnetPLOT/summary.py  /tmp/cpunetlog/2024-03-01_10:53:55-agreeable-agama.cnl
# Out:
# === Summary ===
# Filename:  2024-03-01_10:53:55-agreeable-agama.cnl
# Comment:
# Hostname:  agreeable-agama
# Kernel:    5.15.0-97-generic
#
# Start:     2024-03-01_10:53:58
# End:       2024-03-01_10:55:00
# Duration:  62
#
# CPUs: CPU0, CPU1
# NICs: sv1-eth1, sv1-eth2
#
# == Average transmission rates ==
# sv1-eth1.send:       0.01 MBits/s
# sv1-eth1.receive:        0.5 MBits/s
# sv1-eth2.send:       0.01 MBits/s
# sv1-eth2.receive:       0.49 MBits/s

# %% [markdown]
# Aufgabe 2.4 1 UDP 1 TCP Strom Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2024-03-01_10:56:27-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_10:56:27-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_10:56:27",
#         1709286987.8445113
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 2.4 1 UDP 1 TCP Strom Summary

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:30:44-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:30:44-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:30:47
# End:       2023-12-20_01:31:57
# Duration:  70
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1, sv1-eth2
#
# == Average transmission rates ==
# sv1-eth1.send:        0.0 MBits/s
# sv1-eth1.receive:       0.28 MBits/s
# sv1-eth2.send:        0.0 MBits/s
# sv1-eth2.receive:        0.7 MBits/s

# %% [markdown]
# Aufgabe 3.1 5% Loss TCP Cwnd

# %% [markdown]
# iperf3 -c 10.11.0.3 -Z -t 60
# Connecting to host 10.11.0.3, port 5201
# [  5] local 10.11.0.1 port 34528 connected to 10.11.0.3 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   233 KBytes  1.91 Mbits/sec    4   7.07 KBytes
# [  5]   1.00-2.00   sec   134 KBytes  1.10 Mbits/sec    7   11.3 KBytes
# [  5]   2.00-3.00   sec   156 KBytes  1.27 Mbits/sec    2   11.3 KBytes
# [  5]   3.00-4.00   sec  93.3 KBytes   764 Kbits/sec    6   5.66 KBytes
# [  5]   4.00-5.00   sec  93.3 KBytes   764 Kbits/sec    6   11.3 KBytes
# [  5]   5.00-6.00   sec  93.3 KBytes   764 Kbits/sec    4   11.3 KBytes
# [  5]   6.00-7.00   sec   187 KBytes  1.53 Mbits/sec    6   5.66 KBytes
# [  5]   7.00-8.00   sec  93.3 KBytes   764 Kbits/sec   10   9.90 KBytes
# [  5]   8.00-9.00   sec  87.7 KBytes   718 Kbits/sec    0   12.7 KBytes
# [  5]   9.00-10.00  sec   165 KBytes  1.36 Mbits/sec    6   11.3 KBytes
# [  5]  10.00-11.00  sec  82.0 KBytes   672 Kbits/sec    4   9.90 KBytes
# [  5]  11.00-12.00  sec  82.0 KBytes   672 Kbits/sec    6   2.83 KBytes
# [  5]  12.00-13.00  sec   164 KBytes  1.34 Mbits/sec    2   12.7 KBytes
# [  5]  13.00-14.00  sec  82.0 KBytes   672 Kbits/sec    2   11.3 KBytes
# [  5]  14.00-15.00  sec   164 KBytes  1.34 Mbits/sec    2   11.3 KBytes
# [  5]  15.00-16.00  sec  82.0 KBytes   672 Kbits/sec    2   12.7 KBytes
# [  5]  16.00-17.00  sec  82.0 KBytes   672 Kbits/sec    0   14.1 KBytes
# [  5]  17.00-18.00  sec   164 KBytes  1.34 Mbits/sec    2   12.7 KBytes
# [  5]  18.00-19.00  sec  82.0 KBytes   672 Kbits/sec    2   9.90 KBytes
# [  5]  19.00-20.00  sec   164 KBytes  1.34 Mbits/sec    4   7.07 KBytes
# [  5]  20.00-21.00  sec  82.0 KBytes   672 Kbits/sec    0   15.6 KBytes
# [  5]  21.00-22.00  sec  82.0 KBytes   672 Kbits/sec    6   4.24 KBytes
# [  5]  22.00-23.00  sec   164 KBytes  1.34 Mbits/sec    3   5.66 KBytes
# [  5]  23.00-24.00  sec  82.0 KBytes   672 Kbits/sec    5   5.66 KBytes
# [  5]  24.00-25.00  sec   164 KBytes  1.34 Mbits/sec    0   14.1 KBytes
# [  5]  25.00-26.00  sec  82.0 KBytes   672 Kbits/sec    2   11.3 KBytes
# [  5]  26.00-27.00  sec   164 KBytes  1.34 Mbits/sec    8   9.90 KBytes
# [  5]  27.00-28.00  sec  82.0 KBytes   672 Kbits/sec    3   8.48 KBytes
# [  5]  28.00-29.00  sec   164 KBytes  1.34 Mbits/sec    7   2.83 KBytes
# [  5]  29.00-30.00  sec  82.0 KBytes   672 Kbits/sec   10   4.24 KBytes
# [  5]  30.00-31.00  sec  82.0 KBytes   672 Kbits/sec    5   8.48 KBytes
# [  5]  31.00-32.00  sec  82.0 KBytes   672 Kbits/sec    2   11.3 KBytes
# [  5]  32.00-33.00  sec   164 KBytes  1.34 Mbits/sec    3   11.3 KBytes
# [  5]  33.00-34.00  sec  82.0 KBytes   672 Kbits/sec    0   15.6 KBytes
# [  5]  34.00-35.00  sec   164 KBytes  1.34 Mbits/sec    7   11.3 KBytes
# [  5]  35.00-36.00  sec  82.0 KBytes   672 Kbits/sec    7   7.07 KBytes
# [  5]  36.00-37.00  sec  82.0 KBytes   672 Kbits/sec    5   9.90 KBytes
# [  5]  37.00-38.00  sec   164 KBytes  1.34 Mbits/sec    9   7.07 KBytes
# [  5]  38.00-39.00  sec  82.0 KBytes   672 Kbits/sec    4   11.3 KBytes
# [  5]  39.00-40.00  sec   164 KBytes  1.34 Mbits/sec    8   2.83 KBytes
# [  5]  40.00-41.00  sec  82.0 KBytes   672 Kbits/sec    8   7.07 KBytes
# [  5]  41.00-42.00  sec  82.0 KBytes   672 Kbits/sec    8   8.48 KBytes
# [  5]  42.00-43.00  sec   164 KBytes  1.34 Mbits/sec    7   7.07 KBytes
# [  5]  43.00-44.00  sec  82.0 KBytes   672 Kbits/sec    0   12.7 KBytes
# [  5]  44.00-45.00  sec   164 KBytes  1.34 Mbits/sec    0   12.7 KBytes
# [  5]  45.00-46.00  sec  82.0 KBytes   672 Kbits/sec    3   9.90 KBytes
# [  5]  46.00-47.00  sec  82.0 KBytes   672 Kbits/sec   12   5.66 KBytes
# [  5]  47.00-48.00  sec   164 KBytes  1.34 Mbits/sec    4   12.7 KBytes
# [  5]  48.00-49.00  sec  82.0 KBytes   672 Kbits/sec    0   14.1 KBytes
# [  5]  49.00-50.00  sec   164 KBytes  1.34 Mbits/sec   10   11.3 KBytes
# [  5]  50.00-51.00  sec  82.0 KBytes   672 Kbits/sec    8   4.24 KBytes
# [  5]  51.00-52.00  sec  82.0 KBytes   672 Kbits/sec    6   9.90 KBytes
# [  5]  52.00-53.00  sec   164 KBytes  1.34 Mbits/sec    5   11.3 KBytes
# [  5]  53.00-54.00  sec  82.0 KBytes   672 Kbits/sec    7   4.24 KBytes
# [  5]  54.00-55.00  sec  82.0 KBytes   671 Kbits/sec    4   8.48 KBytes
# [  5]  55.00-56.01  sec   164 KBytes  1.33 Mbits/sec    3   4.24 KBytes
# [  5]  56.01-57.00  sec  82.0 KBytes   682 Kbits/sec    9   11.3 KBytes
# [  5]  57.00-58.00  sec   164 KBytes  1.34 Mbits/sec    5   9.90 KBytes
# [  5]  58.00-59.00  sec  82.0 KBytes   672 Kbits/sec    2   14.1 KBytes
# [  5]  59.00-60.00  sec   164 KBytes  1.34 Mbits/sec    6   4.24 KBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-60.00  sec  6.91 MBytes   966 Kbits/sec  278             sender
# [  5]   0.00-60.07  sec  6.72 MBytes   939 Kbits/sec                  receiver
#
# iperf Done.

# %% [markdown]
# Aufgabe 3.2 5% Loss TCP Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2024-03-01_11:19:44-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_11:19:44-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_11:19:44",
#         1709288384.6514347
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 3.2 5% Loss TCP Summary

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2024-03-01_11:19:44-agreeable-agama.cnl
# Out:
# === Summary ===
# Filename:  2024-03-01_11:19:44-agreeable-agama.cnl
# Comment:
# Hostname:  agreeable-agama
# Kernel:    5.15.0-97-generic
#
# Start:     2024-03-01_11:19:47
# End:       2024-03-01_11:20:52
# Duration:  66
#
# CPUs: CPU0, CPU1
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.02 MBits/s
# sv1-eth1.receive:        0.9 MBits/s

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Plot c1

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2024-03-01_11:13:56-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_11:13:56-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_11:13:56",
#         1709288036.9594777
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Plot sv1

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2024-03-01_11:13:55-agreeable-agama.cnl
# Out:
# /tmp/cpunetlog/2024-03-01_11:13:55-agreeable-agama.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2024-03-01_11:13:55",
#         1709288035.3795033
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "agreeable-agama",
#         "kernel": "5.15.0-97-generic",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#107-Ubuntu SMP Wed Feb 7 13:26:48 UTC 2024"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Summary c1

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2024-03-01_11:13:56-agreeable-agama.cnl
# Out:
# === Summary ===
# Filename:  2024-03-01_11:13:56-agreeable-agama.cnl
# Comment:
# Hostname:  agreeable-agama
# Kernel:    5.15.0-97-generic
#
# Start:     2024-03-01_11:13:56
# End:       2024-03-01_11:14:58
# Duration:  62
#
# CPUs: CPU0, CPU1
# NICs: c1-eth1
#
# == Average transmission rates ==
# c1-eth1.send:        1.0 MBits/s
# c1-eth1.receive:        0.0 MBits/s

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Summary sv1

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2024-03-01_11:13:55-agreeable-agama.cnl
# Out:
# === Summary ===
# Filename:  2024-03-01_11:13:55-agreeable-agama.cnl
# Comment:
# Hostname:  agreeable-agama
# Kernel:    5.15.0-97-generic
#
# Start:     2024-03-01_11:13:56
# End:       2024-03-01_11:14:59
# Duration:  63
#
# CPUs: CPU0, CPU1
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:        0.0 MBits/s
# sv1-eth1.receive:        0.8 MBits/s
