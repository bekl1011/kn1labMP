# %% [markdown]
# By specifying the path to a cnl_file, you can run the scripts cnl_plot.py and summary.py in this notebook, which also allows the plots to be presented.

# %%
import os

# %% [markdown]
# Aufgabe 1.1 1 TCP Strom CWND

# %%
iperf3 -c 10.11.0.3 -Z -t 60 -w 32K
Connecting to host 10.11.0.3, port 5201
[  5] local 10.11.0.1 port 33364 connected to 10.11.0.3 port 5201
[ ID] Interval           Transfer     Bitrate         Retr  Cwnd
[  5]   0.00-1.00   sec   170 KBytes  1.39 Mbits/sec    0   33.9 KBytes       
[  5]   1.00-2.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   2.00-3.00   sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]   3.00-4.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   4.00-5.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   5.00-6.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   6.00-7.00   sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]   7.00-8.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   8.00-9.00   sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]   9.00-10.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  10.00-11.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  11.00-12.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  12.00-13.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  13.00-14.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  14.00-15.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  15.00-16.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  16.00-17.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  17.00-18.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  18.00-19.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  19.00-20.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  20.00-21.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  21.00-22.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  22.00-23.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  23.00-24.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  24.00-25.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  25.00-26.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  26.00-27.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  27.00-28.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  28.00-29.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  29.00-30.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  30.00-31.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  31.00-32.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  32.00-33.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  33.00-34.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  34.00-35.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  35.00-36.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  36.00-37.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  37.00-38.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  38.00-39.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  39.00-40.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  40.00-41.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  41.00-42.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  42.00-43.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  43.00-44.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  44.00-45.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  45.00-46.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  46.00-47.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  47.00-48.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  48.00-49.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  49.00-50.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  50.00-51.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  51.00-52.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  52.00-53.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  53.00-54.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  54.00-55.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
[  5]  55.00-56.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  56.00-57.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  57.00-58.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  58.00-59.00  sec   124 KBytes  1.02 Mbits/sec    0   33.9 KBytes       
[  5]  59.00-60.00  sec  93.3 KBytes   764 Kbits/sec    0   33.9 KBytes       
- - - - - - - - - - - - - - - - - - - - - - - - -
[ ID] Interval           Transfer     Bitrate         Retr
[  5]   0.00-60.00  sec  6.88 MBytes   962 Kbits/sec    0             sender
[  5]   0.00-60.30  sec  6.87 MBytes   956 Kbits/sec                  receiver

iperf Done.

# %% [markdown]
# Aufgabe 1.2 1 TCP Strom Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011  /tmp/cpunetlog/2023-12-23_01:57:10-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-23_01:57:10-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-23_01:57:10",
#         1703296630.7893803
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }
# /CPUnetPLOT/plot_layout.py:43: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(left=self.left, wspace=self.wspace, right=self.right,

# %% [markdown]
# Aufgabe 1.3 1 TCP Strom Summary

# %%
# %run /CPUnetPLOT/summary.py  /tmp/cpunetlog/2023-12-21_10:08:39-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-21_10:08:39-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-21_10:08:43
# End:       2023-12-21_10:09:43
# Duration:  61
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.02 MBits/s
# sv1-eth1.receive:       0.67 MBits/s

# %% [markdown]
# Aufgabe 2.1 2 TCP Ströme Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:21:18-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:21:18-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:21:18",
#         1703035278.7346325
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 2.2 2 TCP Ströme summary

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:21:18-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:21:18-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:21:22
# End:       2023-12-20_01:22:25
# Duration:  64
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1, sv1-eth2
#
# == Average transmission rates ==
# sv1-eth1.send:       0.01 MBits/s
# sv1-eth1.receive:       0.51 MBits/s
# sv1-eth2.send:       0.01 MBits/s
# sv1-eth2.receive:       0.49 MBits/s

# %% [markdown]
# Aufgabe 2.4 1 UDP 1 TCP Strom Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:30:44-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:30:44-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:30:44",
#         1703035844.753698
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 2.4 1 UDP 1 TCP Strom Summary

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:30:44-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:30:44-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:30:47
# End:       2023-12-20_01:31:57
# Duration:  70
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1, sv1-eth2
#
# == Average transmission rates ==
# sv1-eth1.send:        0.0 MBits/s
# sv1-eth1.receive:       0.28 MBits/s
# sv1-eth2.send:        0.0 MBits/s
# sv1-eth2.receive:        0.7 MBits/s

# %% [markdown]
# Aufgabe 3.1 5% Loss TCP Cwnd

# %% [markdown]
# iperf3 -c 10.11.0.3 -Z -t 60
# Connecting to host 10.11.0.3, port 5201
# [  5] local 10.11.0.1 port 49472 connected to 10.11.0.3 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   296 KBytes  2.43 Mbits/sec    2   15.6 KBytes
# [  5]   1.00-2.00   sec   127 KBytes  1.04 Mbits/sec    5   4.24 KBytes
# [  5]   2.00-3.00   sec   127 KBytes  1.04 Mbits/sec    9   4.24 KBytes
# [  5]   3.00-4.00   sec   127 KBytes  1.04 Mbits/sec    4   8.48 KBytes
# [  5]   4.00-5.00   sec   127 KBytes  1.04 Mbits/sec    7   5.66 KBytes
# [  5]   5.00-6.00   sec   127 KBytes  1.04 Mbits/sec    6   5.66 KBytes
# [  5]   6.00-7.00   sec  0.00 Bytes  0.00 bits/sec    5   7.07 KBytes
# [  5]   7.00-8.00   sec   127 KBytes  1.04 Mbits/sec    2   7.07 KBytes
# [  5]   8.00-9.00   sec   127 KBytes  1.04 Mbits/sec    5   8.48 KBytes
# [  5]   9.00-10.00  sec   127 KBytes  1.04 Mbits/sec    4   4.24 KBytes
# [  5]  10.00-11.00  sec   127 KBytes  1.04 Mbits/sec    6   5.66 KBytes
# [  5]  11.00-12.00  sec   127 KBytes  1.04 Mbits/sec    7   7.07 KBytes
# [  5]  12.00-13.00  sec   127 KBytes  1.04 Mbits/sec    8   1.41 KBytes
# [  5]  13.00-14.00  sec   127 KBytes  1.04 Mbits/sec    2   11.3 KBytes
# [  5]  14.00-15.00  sec   127 KBytes  1.04 Mbits/sec    6   2.83 KBytes
# [  5]  15.00-16.00  sec  0.00 Bytes  0.00 bits/sec    1   9.90 KBytes
# [  5]  16.00-17.00  sec   127 KBytes  1.04 Mbits/sec    7   2.83 KBytes
# [  5]  17.00-18.00  sec   127 KBytes  1.04 Mbits/sec    5   5.66 KBytes
# [  5]  18.00-19.00  sec   127 KBytes  1.04 Mbits/sec    6   7.07 KBytes
# [  5]  19.00-20.00  sec   127 KBytes  1.04 Mbits/sec    5   4.24 KBytes
# [  5]  20.00-21.00  sec   127 KBytes  1.04 Mbits/sec    6   7.07 KBytes
# [  5]  21.00-22.00  sec   127 KBytes  1.04 Mbits/sec    1   12.7 KBytes
# [  5]  22.00-23.00  sec   127 KBytes  1.04 Mbits/sec    5   8.48 KBytes
# [  5]  23.00-24.00  sec  0.00 Bytes  0.00 bits/sec    6   2.83 KBytes
# [  5]  24.00-25.00  sec   127 KBytes  1.04 Mbits/sec    6   8.48 KBytes
# [  5]  25.00-26.00  sec   127 KBytes  1.04 Mbits/sec    5   4.24 KBytes
# [  5]  26.00-27.00  sec   127 KBytes  1.04 Mbits/sec    3   5.66 KBytes
# [  5]  27.00-28.00  sec   127 KBytes  1.04 Mbits/sec    4   5.66 KBytes
# [  5]  28.00-29.00  sec   127 KBytes  1.04 Mbits/sec    0   14.1 KBytes
# [  5]  29.00-30.00  sec   127 KBytes  1.04 Mbits/sec    5   5.66 KBytes
# [  5]  30.00-31.00  sec   127 KBytes  1.04 Mbits/sec    7   2.83 KBytes
# [  5]  31.00-32.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  32.00-33.00  sec  0.00 Bytes  0.00 bits/sec    3   5.66 KBytes
# [  5]  33.00-34.00  sec   127 KBytes  1.04 Mbits/sec    6   7.07 KBytes
# [  5]  34.00-35.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  35.00-36.00  sec   127 KBytes  1.04 Mbits/sec    8   2.83 KBytes
# [  5]  36.00-37.00  sec   127 KBytes  1.04 Mbits/sec    6   5.66 KBytes
# [  5]  37.00-38.00  sec   127 KBytes  1.04 Mbits/sec    3   8.48 KBytes
# [  5]  38.00-39.00  sec   127 KBytes  1.04 Mbits/sec    7   2.83 KBytes
# [  5]  39.00-40.00  sec   127 KBytes  1.04 Mbits/sec    4   7.07 KBytes
# [  5]  40.00-41.00  sec   127 KBytes  1.04 Mbits/sec    5   9.90 KBytes
# [  5]  41.00-42.00  sec   127 KBytes  1.04 Mbits/sec    9   4.24 KBytes
# [  5]  42.00-43.00  sec  0.00 Bytes  0.00 bits/sec    5   7.07 KBytes
# [  5]  43.00-44.00  sec   127 KBytes  1.04 Mbits/sec    6   2.83 KBytes
# [  5]  44.00-45.00  sec   127 KBytes  1.04 Mbits/sec    3   9.90 KBytes
# [  5]  45.00-46.00  sec   127 KBytes  1.04 Mbits/sec    5   7.07 KBytes
# [  5]  46.00-47.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  47.00-48.00  sec   127 KBytes  1.04 Mbits/sec    3   5.66 KBytes
# [  5]  48.00-49.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  49.00-50.00  sec  0.00 Bytes  0.00 bits/sec    1   11.3 KBytes
# [  5]  50.00-51.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  51.00-52.00  sec   127 KBytes  1.04 Mbits/sec    5   7.07 KBytes
# [  5]  52.00-53.00  sec   127 KBytes  1.04 Mbits/sec    3   7.07 KBytes
# [  5]  53.00-54.00  sec   127 KBytes  1.04 Mbits/sec    2   9.90 KBytes
# [  5]  54.00-55.00  sec   127 KBytes  1.04 Mbits/sec    8   2.83 KBytes
# [  5]  55.00-56.00  sec   127 KBytes  1.04 Mbits/sec    6   5.66 KBytes
# [  5]  56.00-57.00  sec  0.00 Bytes  0.00 bits/sec    5   2.83 KBytes
# [  5]  57.00-58.00  sec   127 KBytes  1.04 Mbits/sec   10   2.83 KBytes
# [  5]  58.00-59.00  sec   127 KBytes  1.04 Mbits/sec    1   9.90 KBytes
# [  5]  59.00-60.00  sec   127 KBytes  1.04 Mbits/sec    6   8.48 KBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-60.00  sec  6.75 MBytes   944 Kbits/sec  285             sender
# [  5]   0.00-60.11  sec  6.58 MBytes   918 Kbits/sec                  receiver
#
# iperf Done.

# %% [markdown]
# iperf3 -c 10.11.0.3 -Z -t 60 -w 32K
# Connecting to host 10.11.0.3, port 5201
# [  5] local 10.11.0.1 port 60930 connected to 10.11.0.3 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   181 KBytes  1.48 Mbits/sec    4   11.3 KBytes
# [  5]   1.00-2.00   sec  93.3 KBytes   764 Kbits/sec    3   8.48 KBytes
# [  5]   2.00-3.00   sec   124 KBytes  1.02 Mbits/sec    1   11.3 KBytes
# [  5]   3.00-4.00   sec   124 KBytes  1.02 Mbits/sec    2   9.90 KBytes
# [  5]   4.00-5.00   sec   124 KBytes  1.02 Mbits/sec    3   5.66 KBytes
# [  5]   5.00-6.00   sec  93.3 KBytes   764 Kbits/sec    4   7.07 KBytes
# [  5]   6.00-7.00   sec   124 KBytes  1.02 Mbits/sec    5   5.66 KBytes
# [  5]   7.00-8.00   sec   124 KBytes  1.02 Mbits/sec    7   5.66 KBytes
# [  5]   8.00-9.00   sec  93.3 KBytes   764 Kbits/sec    3   5.66 KBytes
# [  5]   9.00-10.00  sec   124 KBytes  1.02 Mbits/sec    4   5.66 KBytes
# [  5]  10.00-11.00  sec   124 KBytes  1.02 Mbits/sec    4   7.07 KBytes
# [  5]  11.00-12.00  sec   124 KBytes  1.02 Mbits/sec    4   7.07 KBytes
# [  5]  12.00-13.00  sec  93.3 KBytes   764 Kbits/sec    6   4.24 KBytes
# [  5]  13.00-14.00  sec  62.2 KBytes   510 Kbits/sec    3   1.41 KBytes
# [  5]  14.00-15.00  sec  93.3 KBytes   765 Kbits/sec    3   8.48 KBytes
# [  5]  15.00-16.00  sec   124 KBytes  1.02 Mbits/sec    2   9.90 KBytes
# [  5]  16.00-17.00  sec  93.3 KBytes   764 Kbits/sec    3   7.07 KBytes
# [  5]  17.00-18.00  sec   124 KBytes  1.02 Mbits/sec    2   7.07 KBytes
# [  5]  18.00-19.00  sec   124 KBytes  1.02 Mbits/sec    5   4.24 KBytes
# [  5]  19.00-20.00  sec   124 KBytes  1.02 Mbits/sec    4   5.66 KBytes
# [  5]  20.00-21.00  sec  93.3 KBytes   764 Kbits/sec    5   5.66 KBytes
# [  5]  21.00-22.00  sec   124 KBytes  1.02 Mbits/sec    4   5.66 KBytes
# [  5]  22.00-23.00  sec   124 KBytes  1.02 Mbits/sec    0   14.1 KBytes
# [  5]  23.00-24.00  sec  93.3 KBytes   764 Kbits/sec    3   5.66 KBytes
# [  5]  24.00-25.00  sec   124 KBytes  1.02 Mbits/sec    3   9.90 KBytes
# [  5]  25.00-26.00  sec   124 KBytes  1.02 Mbits/sec    7   4.24 KBytes
# [  5]  26.00-27.00  sec  93.3 KBytes   764 Kbits/sec    4   5.66 KBytes
# [  5]  27.00-28.00  sec   124 KBytes  1.02 Mbits/sec    7   9.90 KBytes
# [  5]  28.00-29.00  sec   124 KBytes  1.02 Mbits/sec    2   7.07 KBytes
# [  5]  29.00-30.00  sec  93.3 KBytes   764 Kbits/sec    4   5.66 KBytes
# [  5]  30.00-31.00  sec   124 KBytes  1.02 Mbits/sec    5   5.66 KBytes
# [  5]  31.00-32.00  sec   124 KBytes  1.02 Mbits/sec    4   5.66 KBytes
# [  5]  32.00-33.00  sec  93.3 KBytes   764 Kbits/sec    5   5.66 KBytes
# [  5]  33.00-34.00  sec   124 KBytes  1.02 Mbits/sec    6   5.66 KBytes
# [  5]  34.00-35.00  sec   124 KBytes  1.02 Mbits/sec    7   5.66 KBytes
# [  5]  35.00-36.00  sec  93.3 KBytes   764 Kbits/sec    3   8.48 KBytes
# [  5]  36.00-37.00  sec   124 KBytes  1.02 Mbits/sec    9   4.24 KBytes
# [  5]  37.00-38.00  sec   124 KBytes  1.02 Mbits/sec    3   9.90 KBytes
# [  5]  38.00-39.00  sec  93.3 KBytes   764 Kbits/sec    1   11.3 KBytes
# [  5]  39.00-40.00  sec   124 KBytes  1.02 Mbits/sec    2   14.1 KBytes
# [  5]  40.00-41.00  sec   124 KBytes  1.02 Mbits/sec    6   5.66 KBytes
# [  5]  41.00-42.00  sec   124 KBytes  1.02 Mbits/sec    1   9.90 KBytes
# [  5]  42.00-43.00  sec  93.3 KBytes   764 Kbits/sec    1   11.3 KBytes
# [  5]  43.00-44.00  sec   124 KBytes  1.02 Mbits/sec    1   12.7 KBytes
# [  5]  44.00-45.00  sec   124 KBytes  1.02 Mbits/sec    4   4.24 KBytes
# [  5]  45.00-46.00  sec   124 KBytes  1.02 Mbits/sec    9   4.24 KBytes
# [  5]  46.00-47.00  sec  93.3 KBytes   764 Kbits/sec    4   8.48 KBytes
# [  5]  47.00-48.00  sec   124 KBytes  1.02 Mbits/sec    6   5.66 KBytes
# [  5]  48.00-49.00  sec   124 KBytes  1.02 Mbits/sec    3   4.24 KBytes
# [  5]  49.00-50.00  sec  93.3 KBytes   764 Kbits/sec    3   8.48 KBytes
# [  5]  50.00-51.00  sec   124 KBytes  1.02 Mbits/sec    4   5.66 KBytes
# [  5]  51.00-52.00  sec  93.3 KBytes   764 Kbits/sec    5   4.24 KBytes
# [  5]  52.00-53.00  sec   124 KBytes  1.02 Mbits/sec    6   4.24 KBytes
# [  5]  53.00-54.00  sec   124 KBytes  1.02 Mbits/sec    8   2.83 KBytes
# [  5]  54.00-55.00  sec  93.3 KBytes   764 Kbits/sec    4   5.66 KBytes
# [  5]  55.00-56.00  sec   124 KBytes  1.02 Mbits/sec    5   8.48 KBytes
# [  5]  56.00-57.00  sec   124 KBytes  1.02 Mbits/sec    0   15.6 KBytes
# [  5]  57.00-58.00  sec   130 KBytes  1.07 Mbits/sec    2   15.6 KBytes
# [  5]  58.00-59.00  sec  93.3 KBytes   764 Kbits/sec    4   8.48 KBytes
# [  5]  59.00-60.00  sec   124 KBytes  1.02 Mbits/sec   10   4.24 KBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-60.00  sec  6.71 MBytes   939 Kbits/sec  242             sender
# [  5]   0.00-60.08  sec  6.66 MBytes   930 Kbits/sec                  receiver
#
# iperf Done.

# %% [markdown]
# Aufgabe 3.2 5% Loss TCP Plot

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:34:27-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:34:27-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:34:27",
#         1703036067.6346157
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# w flag

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:36:31-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:36:31-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:36:31",
#         1703036191.692464
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 3.2 5% Loss TCP Summary

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:34:27-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:34:27-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:34:27
# End:       2023-12-20_01:35:33
# Duration:  66
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.03 MBits/s
# sv1-eth1.receive:        0.8 MBits/s

# %% [markdown]
# w flag

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:36:31-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:36:31-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:36:34
# End:       2023-12-20_01:37:34
# Duration:  61
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.03 MBits/s
# sv1-eth1.receive:       0.96 MBits/s

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Plot c1

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:41:42-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:41:42-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:41:42",
#         1703036502.119845
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Plot sv1

# %%
# %run /CPUnetPLOT/cnl_plot.py -nsc 0.0011 /tmp/cpunetlog/2023-12-20_01:46:50-830dd1dd9ebe.cnl
# Out:
# /tmp/cpunetlog/2023-12-20_01:46:50-830dd1dd9ebe.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2023-12-20_01:46:50",
#         1703036810.0743148
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "830dd1dd9ebe",
#         "kernel": "6.4.16-linuxkit",
#         "machine": "x86_64",
#         "sysname": "Linux",
#         "version": "#1 SMP PREEMPT_DYNAMIC Fri Nov 10 14:51:57 UTC 2023"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Summary c1

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:41:42-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:41:42-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:41:44
# End:       2023-12-20_01:42:49
# Duration:  66
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: c1-eth1
#
# == Average transmission rates ==
# c1-eth1.send:       0.94 MBits/s
# c1-eth1.receive:        0.0 MBits/s

# %% [markdown]
# Aufgabe 4.1 10 % Loss UDP Summary sv1

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2023-12-20_01:46:50-830dd1dd9ebe.cnl
# Out:
# === Summary ===
# Filename:  2023-12-20_01:46:50-830dd1dd9ebe.cnl
# Comment:
# Hostname:  830dd1dd9ebe
# Kernel:    6.4.16-linuxkit
#
# Start:     2023-12-20_01:46:56
# End:       2023-12-20_01:48:03
# Duration:  67
#
# CPUs: CPU0, CPU1, CPU2, CPU3, CPU4, CPU5, CPU6, CPU7
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:        0.0 MBits/s
# sv1-eth1.receive:       0.83 MBits/s
